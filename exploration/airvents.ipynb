# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data extraction + cleaning

# %%
df = pd.read_csv(r'C:\Users\mkavalio\codedir\TextAnalysis\Data\Airvents_survey(Form1).csv')

# %%
df.head()
# Out:
#    ID        Start time   Completion time  \
# 0   1  1/13/22 17:24:56  1/13/22 17:27:40
# 1   2  1/13/22 17:25:55  1/13/22 17:27:50
# 2   3  1/13/22 17:30:25  1/13/22 17:32:02
# 3   4  1/13/22 17:31:51  1/13/22 17:33:38
# 4   5  1/13/22 17:31:46  1/13/22 17:34:08
#
#   How often do you change the air flow in your car?  \
# 0                                             Often
# 1                                         Sometimes
# 2                                            Rarely
# 3                                            Rarely
# 4                                         Sometimes
#
#   Lets say that you are sitting in your car, ready to drive to work, and you think it blows too much from the air vents, what do you do?  \
# 0                                                NaN
# 1  Change the air intensity using the center display
# 2                                                NaN
# 3                                                NaN
# ...

# %%
df['What do you do when it blows too much from the airventils'] = \
df['Lets say that you are sitting in your car, ready to drive to work, and you think it blows too much from the air vents, what do you do?'].fillna('') + ' ' + \
df['Lets say that you are sitting in your car, ready to drive to work, and you think it blows too much from the air vents, what do you do?2'].fillna('') + ' ' + \
df['Lets say that you are sitting in your car, ready to drive to work, and you think it blows too much from the air vents, what do you do?3'].fillna('')

# %%
df.drop(['Lets say that you are sitting in your car, ready to drive to work, and you think it blows too much from the air vents, what do you do?','Lets say that you are sitting in your car, ready to drive to work, and you think it blows too much from the air vents, what do you do?2','Lets say that you are sitting in your car, ready to drive to work, and you think it blows too much from the air vents, what do you do?3'], axis=1, inplace=True)

# %%
df.drop(['Start time', 'Completion time',], axis=1, inplace=True)

# %%
df.rename(columns={'Which air vents do you usually change?':'Which air vents do you usually change?0'}, inplace=True)

# %%
df['Which airvents do you usually change?'] = \
df['Which air vents do you usually change?0'].fillna('') + ' ' + \
df['Which air vents do you usually change?'].fillna('') + ' ' + \
df['Which air vents do you usually change?2'].fillna('')

df['Which airvents do you usually move away from you?'] = \
df['Which air vents do you usually move away from you?'].fillna('') + ' ' + \
df['Which air vents do you usually move away from you?2'].fillna('') + ' ' + \
df['Which air vents do you usually move away from you?3'].fillna('')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 11 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   ID                                                         241 non-null    int64
#  1   How often do you change the air flow in your car?          241 non-null    object
#  2   When you change, do you usually change to                  15 non-null     object
#  3   What kind of car do you drive the most?                    241 non-null    object
#  4   What direction du you usually move them?                   161 non-null    object
#  5   If you change, what is usually the main reason?2           241 non-null    object
#  6   How is the weather where you live?                         241 non-null    object
#  7   Which city do you live in?                                 241 non-null    object
# ...

# %%
df.drop(['Which air vents do you usually change?2', 'Which air vents do you usually change?0', 'Which air vents do you usually change?', 
         'Which air vents do you usually move away from you?2', 'Which air vents do you usually move away from you?3', 'Which air vents do you usually move away from you?'], axis=1, inplace=True)

# %%
df.drop(['When you move the air, which air vents do you change?',], axis=1, inplace=True)

# %%
df.loc[~pd.isna(df['Which airvents do you usually change?'])]
# Out:
#       ID How often do you change the air flow in your car?  \
# 0      1                                             Often
# 1      2                                         Sometimes
# 2      3                                            Rarely
# 3      4                                            Rarely
# 4      5                                         Sometimes
# ..   ...                                               ...
# 236  237                                         Sometimes
# 237  238                                         Sometimes
# 238  239                                             Never
# 239  240                                             Often
# 240  241                                            Rarely
#
#     When you change, do you usually change to  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# ...

# %%
df.head()
# Out:
#    ID How often do you change the air flow in your car?  \
# 0   1                                             Often
# 1   2                                         Sometimes
# 2   3                                            Rarely
# 3   4                                            Rarely
# 4   5                                         Sometimes
#
#   When you change, do you usually change to  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   What kind of car do you drive the most?  \
# 0                                    XC90
# 1                               V90 / S90
# 2                                    XC90
# 3                                    XC90
# 4                               V90 / S90
#
#   What direction du you usually move them?  \
# 0                                      NaN
# ...

# %% [markdown]
# # Model
